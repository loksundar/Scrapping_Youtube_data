# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Jul 25 03:21:39 2020

@author: LOKSUNDAR
"""
from selenium import webdriver 
import pandas as pd 
import pandas as pd
import numpy as np
import time
df = pd.read_csv("url.csv",header=None)
df = df.drop([0],axis=1)
df.rename(columns={1:"urls"},inplace=True)
df = df.iloc[1:,:]
df.head()
lst = list(df['urls'])
lst = lst[:560]
def stripping_views(c):
    res=''
    for i in c.strip().split()[0].split(','):
        res = res+i
    return int(res)
views = list()
date = list()
likes = list()
dlikes =list()
comments = list()
comcount=list()
wasteurl = list()
l = 0
driver = webdriver.Firefox(executable_path=r'C:\Users\LOKSUNDAR\Dropbox\Kofluence project\geckodriver.exe')
for url in lst:
        driver.get(url)
        time.sleep(3)
        ele = driver.find_elements_by_class_name("style-scope ytd-video-primary-info-renderer")
        for vid in ele:
            view =vid.find_element_by_xpath('.//*[@id="count"]/yt-view-count-renderer/span[1]').text
            views.append(view)
            date.append(vid.find_element_by_xpath('.//*[@id="date"]/yt-formatted-string').text)
            lik = vid.find_elements_by_xpath('.//*[@id="text"]')
            likes.append(lik[0].text)
            dlikes.append(lik[1].text)
            driver.execute_script("window.scrollTo(0,720)")
            time.sleep(3)
            try :
                com = driver.find_elements_by_class_name('style-scope ytd-comment-renderer')[0].find_elements_by_xpath('//*[@id="content-text"]')
                co = list()
                for j in com:
                    co.append(j.text)
                comments.append(co)
                comcount.append(len(co))
            except:
                comments.append("no Comments ")
                comcount.append(0)
        l=l+1
        print(l,"links are completed out of ",len(lst))
        if (len(ele) == 0):
            wasteurl.append(url)
            print("this url:-",url," is not working")
for i in wasteurl:
    lst.remove(i)
# Out:
# 1 links are completed out of  560
# 2 links are completed out of  560
# 3 links are completed out of  560
# 4 links are completed out of  560
# 5 links are completed out of  560
# 6 links are completed out of  560
# 7 links are completed out of  560
# 8 links are completed out of  560
# 9 links are completed out of  560
# 10 links are completed out of  560
# 11 links are completed out of  560
# 12 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=s5BvjDizm80  is not working
# 13 links are completed out of  560
# 14 links are completed out of  560
# 15 links are completed out of  560
# 16 links are completed out of  560
# 17 links are completed out of  560
# 18 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=rdQvGZDUDJA  is not working
# 19 links are completed out of  560
# 20 links are completed out of  560
# 21 links are completed out of  560
# 22 links are completed out of  560
# 23 links are completed out of  560
# 24 links are completed out of  560
# 25 links are completed out of  560
# 26 links are completed out of  560
# 27 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=2PaTs4s2Ybw  is not working
# 28 links are completed out of  560
# 29 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=IbF3zeUQ1cI  is not working
# 30 links are completed out of  560
# 31 links are completed out of  560
# 32 links are completed out of  560
# 33 links are completed out of  560
# 34 links are completed out of  560
# 35 links are completed out of  560
# 36 links are completed out of  560
# 37 links are completed out of  560
# 38 links are completed out of  560
# 39 links are completed out of  560
# 40 links are completed out of  560
# 41 links are completed out of  560
# 42 links are completed out of  560
# 43 links are completed out of  560
# 44 links are completed out of  560
# 45 links are completed out of  560
# 46 links are completed out of  560
# 47 links are completed out of  560
# 48 links are completed out of  560
# 49 links are completed out of  560
# 50 links are completed out of  560
# 51 links are completed out of  560
# 52 links are completed out of  560
# 53 links are completed out of  560
# 54 links are completed out of  560
# 55 links are completed out of  560
# 56 links are completed out of  560
# 57 links are completed out of  560
# 58 links are completed out of  560
# 59 links are completed out of  560
# 60 links are completed out of  560
# 61 links are completed out of  560
# 62 links are completed out of  560
# 63 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=F0PPPvVTNnE  is not working
# 64 links are completed out of  560
# 65 links are completed out of  560
# 66 links are completed out of  560
# 67 links are completed out of  560
# 68 links are completed out of  560
# 69 links are completed out of  560
# 70 links are completed out of  560
# 71 links are completed out of  560
# 72 links are completed out of  560
# 73 links are completed out of  560
# 74 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=h3fwy3aEqHg  is not working
# 75 links are completed out of  560
# 76 links are completed out of  560
# 77 links are completed out of  560
# 78 links are completed out of  560
# 79 links are completed out of  560
# 80 links are completed out of  560
# 81 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=CgeS-eyScKc  is not working
# 82 links are completed out of  560
# 83 links are completed out of  560
# 84 links are completed out of  560
# 85 links are completed out of  560
# 86 links are completed out of  560
# 87 links are completed out of  560
# 88 links are completed out of  560
# 89 links are completed out of  560
# 90 links are completed out of  560
# 91 links are completed out of  560
# 92 links are completed out of  560
# 93 links are completed out of  560
# 94 links are completed out of  560
# 95 links are completed out of  560
# 96 links are completed out of  560
# 97 links are completed out of  560
# 98 links are completed out of  560
# 99 links are completed out of  560
# 100 links are completed out of  560
# 101 links are completed out of  560
# 102 links are completed out of  560
# 103 links are completed out of  560
# 104 links are completed out of  560
# 105 links are completed out of  560
# 106 links are completed out of  560
# 107 links are completed out of  560
# 108 links are completed out of  560
# 109 links are completed out of  560
# 110 links are completed out of  560
# 111 links are completed out of  560
# 112 links are completed out of  560
# 113 links are completed out of  560
# 114 links are completed out of  560
# 115 links are completed out of  560
# 116 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=SjoG8R9W8E8  is not working
# 117 links are completed out of  560
# 118 links are completed out of  560
# 119 links are completed out of  560
# 120 links are completed out of  560
# 121 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=cg3wlmWexTg  is not working
# 122 links are completed out of  560
# 123 links are completed out of  560
# 124 links are completed out of  560
# 125 links are completed out of  560
# 126 links are completed out of  560
# 127 links are completed out of  560
# 128 links are completed out of  560
# 129 links are completed out of  560
# 130 links are completed out of  560
# 131 links are completed out of  560
# 132 links are completed out of  560
# 133 links are completed out of  560
# 134 links are completed out of  560
# 135 links are completed out of  560
# 136 links are completed out of  560
# 137 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=80KCUIO5wyw  is not working
# 138 links are completed out of  560
# 139 links are completed out of  560
# 140 links are completed out of  560
# 141 links are completed out of  560
# 142 links are completed out of  560
# 143 links are completed out of  560
# 144 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=_iAXFl9ybFU  is not working
# 145 links are completed out of  560
# 146 links are completed out of  560
# 147 links are completed out of  560
# 148 links are completed out of  560
# 149 links are completed out of  560
# 150 links are completed out of  560
# 151 links are completed out of  560
# 152 links are completed out of  560
# 153 links are completed out of  560
# 154 links are completed out of  560
# 155 links are completed out of  560
# 156 links are completed out of  560
# 157 links are completed out of  560
# 158 links are completed out of  560
# 159 links are completed out of  560
# 160 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=I-1SR3xQhrM  is not working
# 161 links are completed out of  560
# 162 links are completed out of  560
# 163 links are completed out of  560
# 164 links are completed out of  560
# 165 links are completed out of  560
# 166 links are completed out of  560
# 167 links are completed out of  560
# 168 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=KkpyTftuQWI  is not working
# 169 links are completed out of  560
# 170 links are completed out of  560
# 171 links are completed out of  560
# 172 links are completed out of  560
# 173 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=KF5ToXPbX98  is not working
# 174 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=5qegXWyXUno  is not working
# 175 links are completed out of  560
# 176 links are completed out of  560
# 177 links are completed out of  560
# 178 links are completed out of  560
# 179 links are completed out of  560
# 180 links are completed out of  560
# 181 links are completed out of  560
# 182 links are completed out of  560
# 183 links are completed out of  560
# 184 links are completed out of  560
# 185 links are completed out of  560
# 186 links are completed out of  560
# 187 links are completed out of  560
# 188 links are completed out of  560
# 189 links are completed out of  560
# 190 links are completed out of  560
# 191 links are completed out of  560
# 192 links are completed out of  560
# 193 links are completed out of  560
# 194 links are completed out of  560
# 195 links are completed out of  560
# 196 links are completed out of  560
# 197 links are completed out of  560
# 198 links are completed out of  560
# 199 links are completed out of  560
# 200 links are completed out of  560
# 201 links are completed out of  560
# 202 links are completed out of  560
# 203 links are completed out of  560
# 204 links are completed out of  560
# 205 links are completed out of  560
# 206 links are completed out of  560
# 207 links are completed out of  560
# 208 links are completed out of  560
# 209 links are completed out of  560
# 210 links are completed out of  560
# 211 links are completed out of  560
# 212 links are completed out of  560
# 213 links are completed out of  560
# 214 links are completed out of  560
# 215 links are completed out of  560
# 216 links are completed out of  560
# 217 links are completed out of  560
# 218 links are completed out of  560
# 219 links are completed out of  560
# 220 links are completed out of  560
# 221 links are completed out of  560
# 222 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=4dVPtu-NLz8  is not working
# 223 links are completed out of  560
# 224 links are completed out of  560
# 225 links are completed out of  560
# 226 links are completed out of  560
# 227 links are completed out of  560
# 228 links are completed out of  560
# 229 links are completed out of  560
# 230 links are completed out of  560
# 231 links are completed out of  560
# 232 links are completed out of  560
# 233 links are completed out of  560
# 234 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=m8KbogJntZs  is not working
# 235 links are completed out of  560
# 236 links are completed out of  560
# 237 links are completed out of  560
# 238 links are completed out of  560
# 239 links are completed out of  560
# 240 links are completed out of  560
# 241 links are completed out of  560
# 242 links are completed out of  560
# 243 links are completed out of  560
# 244 links are completed out of  560
# 245 links are completed out of  560
# 246 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=ceT1Tvcn78Q  is not working
# 247 links are completed out of  560
# 248 links are completed out of  560
# 249 links are completed out of  560
# 250 links are completed out of  560
# 251 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=5vtYU6uVECs  is not working
# 252 links are completed out of  560
# 253 links are completed out of  560
# 254 links are completed out of  560
# 255 links are completed out of  560
# 256 links are completed out of  560
# 257 links are completed out of  560
# 258 links are completed out of  560
# 259 links are completed out of  560
# 260 links are completed out of  560
# 261 links are completed out of  560
# 262 links are completed out of  560
# 263 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=GKm_7jc7MLQ  is not working
# 264 links are completed out of  560
# 265 links are completed out of  560
# 266 links are completed out of  560
# 267 links are completed out of  560
# 268 links are completed out of  560
# 269 links are completed out of  560
# 270 links are completed out of  560
# 271 links are completed out of  560
# 272 links are completed out of  560
# 273 links are completed out of  560
# 274 links are completed out of  560
# 275 links are completed out of  560
# 276 links are completed out of  560
# 277 links are completed out of  560
# 278 links are completed out of  560
# 279 links are completed out of  560
# 280 links are completed out of  560
# 281 links are completed out of  560
# 282 links are completed out of  560
# 283 links are completed out of  560
# 284 links are completed out of  560
# 285 links are completed out of  560
# 286 links are completed out of  560
# 287 links are completed out of  560
# 288 links are completed out of  560
# 289 links are completed out of  560
# 290 links are completed out of  560
# 291 links are completed out of  560
# 292 links are completed out of  560
# 293 links are completed out of  560
# 294 links are completed out of  560
# 295 links are completed out of  560
# 296 links are completed out of  560
# 297 links are completed out of  560
# 298 links are completed out of  560
# 299 links are completed out of  560
# 300 links are completed out of  560
# 301 links are completed out of  560
# 302 links are completed out of  560
# 303 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=EHsIPaq_96U  is not working
# 304 links are completed out of  560
# 305 links are completed out of  560
# 306 links are completed out of  560
# 307 links are completed out of  560
# 308 links are completed out of  560
# 309 links are completed out of  560
# 310 links are completed out of  560
# 311 links are completed out of  560
# 312 links are completed out of  560
# 313 links are completed out of  560
# 314 links are completed out of  560
# 315 links are completed out of  560
# 316 links are completed out of  560
# 317 links are completed out of  560
# 318 links are completed out of  560
# 319 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=3xk5yYLLUFE  is not working
# 320 links are completed out of  560
# 321 links are completed out of  560
# 322 links are completed out of  560
# 323 links are completed out of  560
# 324 links are completed out of  560
# 325 links are completed out of  560
# 326 links are completed out of  560
# 327 links are completed out of  560
# 328 links are completed out of  560
# 329 links are completed out of  560
# 330 links are completed out of  560
# 331 links are completed out of  560
# 332 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=KqpIKsMyHz4  is not working
# 333 links are completed out of  560
# 334 links are completed out of  560
# 335 links are completed out of  560
# 336 links are completed out of  560
# 337 links are completed out of  560
# 338 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=iDwZ-tJpS5E  is not working
# 339 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=reUAf6PZhqk  is not working
# 340 links are completed out of  560
# 341 links are completed out of  560
# 342 links are completed out of  560
# 343 links are completed out of  560
# 344 links are completed out of  560
# 345 links are completed out of  560
# 346 links are completed out of  560
# 347 links are completed out of  560
# 348 links are completed out of  560
# 349 links are completed out of  560
# 350 links are completed out of  560
# 351 links are completed out of  560
# 352 links are completed out of  560
# 353 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=MSzWfFjKsF8  is not working
# 354 links are completed out of  560
# 355 links are completed out of  560
# 356 links are completed out of  560
# 357 links are completed out of  560
# 358 links are completed out of  560
# 359 links are completed out of  560
# 360 links are completed out of  560
# 361 links are completed out of  560
# 362 links are completed out of  560
# 363 links are completed out of  560
# 364 links are completed out of  560
# 365 links are completed out of  560
# 366 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=iy_QK4jmvmk  is not working
# 367 links are completed out of  560
# 368 links are completed out of  560
# 369 links are completed out of  560
# 370 links are completed out of  560
# 371 links are completed out of  560
# 372 links are completed out of  560
# 373 links are completed out of  560
# 374 links are completed out of  560
# 375 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=wYHbbqfjBu0  is not working
# 376 links are completed out of  560
# 377 links are completed out of  560
# 378 links are completed out of  560
# 379 links are completed out of  560
# 380 links are completed out of  560
# 381 links are completed out of  560
# 382 links are completed out of  560
# 383 links are completed out of  560
# 384 links are completed out of  560
# 385 links are completed out of  560
# 386 links are completed out of  560
# 387 links are completed out of  560
# 388 links are completed out of  560
# 389 links are completed out of  560
# 390 links are completed out of  560
# 391 links are completed out of  560
# 392 links are completed out of  560
# 393 links are completed out of  560
# 394 links are completed out of  560
# 395 links are completed out of  560
# 396 links are completed out of  560
# 397 links are completed out of  560
# 398 links are completed out of  560
# 399 links are completed out of  560
# 400 links are completed out of  560
# 401 links are completed out of  560
# 402 links are completed out of  560
# 403 links are completed out of  560
# 404 links are completed out of  560
# 405 links are completed out of  560
# 406 links are completed out of  560
# 407 links are completed out of  560
# 408 links are completed out of  560
# 409 links are completed out of  560
# 410 links are completed out of  560
# 411 links are completed out of  560
# 412 links are completed out of  560
# 413 links are completed out of  560
# 414 links are completed out of  560
# 415 links are completed out of  560
# 416 links are completed out of  560
# 417 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=wbfh9FGvIxo  is not working
# 418 links are completed out of  560
# 419 links are completed out of  560
# 420 links are completed out of  560
# 421 links are completed out of  560
# 422 links are completed out of  560
# 423 links are completed out of  560
# 424 links are completed out of  560
# 425 links are completed out of  560
# 426 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=PquC2zoIMWs  is not working
# 427 links are completed out of  560
# 428 links are completed out of  560
# 429 links are completed out of  560
# 430 links are completed out of  560
# 431 links are completed out of  560
# 432 links are completed out of  560
# 433 links are completed out of  560
# 434 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=OW-IGxXgFiM  is not working
# 435 links are completed out of  560
# 436 links are completed out of  560
# 437 links are completed out of  560
# 438 links are completed out of  560
# 439 links are completed out of  560
# 440 links are completed out of  560
# 441 links are completed out of  560
# 442 links are completed out of  560
# 443 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=o8sBZEJpzB8  is not working
# 444 links are completed out of  560
# 445 links are completed out of  560
# 446 links are completed out of  560
# 447 links are completed out of  560
# 448 links are completed out of  560
# 449 links are completed out of  560
# 450 links are completed out of  560
# 451 links are completed out of  560
# 452 links are completed out of  560
# 453 links are completed out of  560
# 454 links are completed out of  560
# 455 links are completed out of  560
# 456 links are completed out of  560
# 457 links are completed out of  560
# 458 links are completed out of  560
# 459 links are completed out of  560
# 460 links are completed out of  560
# 461 links are completed out of  560
# 462 links are completed out of  560
# 463 links are completed out of  560
# 464 links are completed out of  560
# 465 links are completed out of  560
# 466 links are completed out of  560
# 467 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=Ixlz6QLjenE  is not working
# 468 links are completed out of  560
# 469 links are completed out of  560
# 470 links are completed out of  560
# 471 links are completed out of  560
# 472 links are completed out of  560
# 473 links are completed out of  560
# 474 links are completed out of  560
# 475 links are completed out of  560
# 476 links are completed out of  560
# 477 links are completed out of  560
# 478 links are completed out of  560
# 479 links are completed out of  560
# 480 links are completed out of  560
# 481 links are completed out of  560
# 482 links are completed out of  560
# 483 links are completed out of  560
# 484 links are completed out of  560
# 485 links are completed out of  560
# 486 links are completed out of  560
# 487 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=h3RgUc0oY-c  is not working
# 488 links are completed out of  560
# 489 links are completed out of  560
# 490 links are completed out of  560
# 491 links are completed out of  560
# 492 links are completed out of  560
# 493 links are completed out of  560
# 494 links are completed out of  560
# 495 links are completed out of  560
# 496 links are completed out of  560
# 497 links are completed out of  560
# 498 links are completed out of  560
# 499 links are completed out of  560
# 500 links are completed out of  560
# 501 links are completed out of  560
# 502 links are completed out of  560
# 503 links are completed out of  560
# 504 links are completed out of  560
# 505 links are completed out of  560
# 506 links are completed out of  560
# 507 links are completed out of  560
# 508 links are completed out of  560
# 509 links are completed out of  560
# 510 links are completed out of  560
# 511 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=1Ab7OPHLKWw  is not working
# 512 links are completed out of  560
# 513 links are completed out of  560
# 514 links are completed out of  560
# 515 links are completed out of  560
# 516 links are completed out of  560
# 517 links are completed out of  560
# 518 links are completed out of  560
# 519 links are completed out of  560
# 520 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=oeIo6NId9-Y  is not working
# 521 links are completed out of  560
# 522 links are completed out of  560
# 523 links are completed out of  560
# 524 links are completed out of  560
# 525 links are completed out of  560
# 526 links are completed out of  560
# 527 links are completed out of  560
# 528 links are completed out of  560
# 529 links are completed out of  560
# 530 links are completed out of  560
# 531 links are completed out of  560
# 532 links are completed out of  560
# 533 links are completed out of  560
# 534 links are completed out of  560
# 535 links are completed out of  560
# 536 links are completed out of  560
# 537 links are completed out of  560
# 538 links are completed out of  560
# 539 links are completed out of  560
# 540 links are completed out of  560
# 541 links are completed out of  560
# 542 links are completed out of  560
# 543 links are completed out of  560
# 544 links are completed out of  560
# 545 links are completed out of  560
# 546 links are completed out of  560
# 547 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=_nNIaPExDj0  is not working
# 548 links are completed out of  560
# 549 links are completed out of  560
# 550 links are completed out of  560
# 551 links are completed out of  560
# 552 links are completed out of  560
# 553 links are completed out of  560
# 554 links are completed out of  560
# 555 links are completed out of  560
# 556 links are completed out of  560
# 557 links are completed out of  560
# 558 links are completed out of  560
# this url:- https://www.youtube.com/watch?v=feHlsGwawio  is not working
# 559 links are completed out of  560
# 560 links are completed out of  560

# %%
nviws = [ stripping_views(i) for i in views]

# %%
df1 = pd.DataFrame()
df1['Vedio Urls'] = lst
df1['No of Views']=nviws
df1['Date Created']=date
df1['NO of Comments']=comcount
df1['comments']=comments
df1['Likes']=likes
df1['Dislikes']=dlikes
df1.to_csv("scrapdata.csv")

# %%
df1.head()
# Out:
#                                     Vedio Urls  No of Views  Date Created  \
# 0  https://www.youtube.com/watch?v=8x94yImf1C8      4668950  Jul 12, 2020
# 1  https://www.youtube.com/watch?v=Y2r0gJYsaHg         1691  Jul 18, 2009
# 2  https://www.youtube.com/watch?v=g22-51Oz3L8     63205782   Aug 9, 2019
# 3  https://www.youtube.com/watch?v=hauXvNQh1Fo          617  Jun 21, 2011
# 4  https://www.youtube.com/watch?v=JqDNRTa641M         5463   Oct 4, 2011
#
#    NO of Comments                                           comments Likes  \
# 0              20  [Pottodiki oka like vesukondi \n  E episode su...   76K
# 1               0                                       no Comments      7
# 2              20  [రానున్న రోజుల్లో ఇలాంటి పాటలకి మంచి ఆదరణ ఉంటు...  189K
# 3               0                                       no Comments      4
# 4               0                                       no Comments     14
#
#   Dislikes
# 0     5.2K
# 1        0
# 2      44K
# 3        0
# 4        1

# %%
print("callme")
# Out:
# callme
